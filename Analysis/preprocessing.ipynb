# %%
import plotly.io as pio
pio.renderers.default="kaggle"

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns',None)
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] =(15,5)

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('../datasets/Airplane_data.csv',index_col=0)

# %%
df.shape
# Out:
# (5268, 12)

# %%
df.size
# Out:
# 63216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5268 entries, 09/17/1908 to 06/08/2009
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time          3049 non-null   object
#  1   Location      5248 non-null   object
#  2   Operator      5250 non-null   object
#  3   Flight #      1069 non-null   object
#  4   Route         3562 non-null   object
#  5   Type          5241 non-null   object
#  6   Registration  4933 non-null   object
#  7   cn/In         4040 non-null   object
#  8   Aboard        5246 non-null   float64
#  9   Fatalities    5256 non-null   float64
#  10  Ground        5246 non-null   float64
#  11  Summary       4878 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 535.0+ KB

# %%
df
# Out:
#              Time                                           Location  \
# Date
# 09/17/1908  17:18                                Fort Myer, Virginia
# 07/12/1912  06:30                            AtlantiCity, New Jersey
# 08/06/1913    NaN                 Victoria, British Columbia, Canada
# 09/09/1913  18:30                                 Over the North Sea
# 10/17/1913  10:30                         Near Johannisthal, Germany
# ...           ...                                                ...
# 05/20/2009  06:30                             Near Madiun, Indonesia
# 05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                                    Operator Flight #  \
# Date
# 09/17/1908             Military - U.S. Army      NaN
# ...

# %%
df.head()
# Out:
#              Time                            Location                Operator  \
# Date
# 09/17/1908  17:18                 Fort Myer, Virginia    Military - U.S. Army
# 07/12/1912  06:30             AtlantiCity, New Jersey    Military - U.S. Navy
# 08/06/1913    NaN  Victoria, British Columbia, Canada                 Private
# 09/09/1913  18:30                  Over the North Sea  Military - German Navy
# 10/17/1913  10:30          Near Johannisthal, Germany  Military - German Navy
#
#            Flight #          Route                    Type Registration cn/In  \
# Date
# 09/17/1908      NaN  Demonstration        Wright Flyer III          NaN     1
# 07/12/1912      NaN    Test flight               Dirigible          NaN   NaN
# 08/06/1913        -            NaN        Curtiss seaplane          NaN   NaN
# 09/09/1913      NaN            NaN  Zeppelin L-1 (airship)          NaN   NaN
# 10/17/1913      NaN            NaN  Zeppelin L-2 (airship)          NaN   NaN
#
# ...

# %%
df.tail()
# Out:
#              Time                                           Location  \
# Date
# 05/20/2009  06:30                             Near Madiun, Indonesia
# 05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                                    Operator Flight #  \
# Date
# 05/20/2009  Military - Indonesian Air Force      NaN
# 05/26/2009                      Service Air      NaN
# 06/01/2009                       Air France      447
# 06/07/2009                       Strait Air      NaN
# 06/08/2009      Military - Indian Air Force      NaN
#
#                                                 Route  \
# Date
# 05/20/2009                           Jakarta - Maduin
# 05/26/2009                               Goma - Isiro
# ...

# %%
df.isin(['NaN']).any()
# Out:
# Time            False
# Location        False
# Operator        False
# Flight #        False
# Route           False
# Type            False
# Registration    False
# cn/In           False
# Aboard          False
# Fatalities      False
# Ground          False
# Summary         False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type', 'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary']

# %%
df['Registration'].unique()
# Out:
# array([nan, '97', '61', ..., '9Q-CSA', 'F-GZCP', 'C-FJJR\xa0'],
#       dtype=object)

# %%
df['Registration'].nunique('Registration')
# Out:
# 4905

# %%
df['Time'].unique()
# Out:
# array(['17:18', '06:30', nan, ..., '01:25', '03:57', '15:32'],
#       dtype=object)

# %%
df.isnull()
# Out:
#              Time  Location  Operator  Flight #  Route   Type  Registration  \
# Date
# 09/17/1908  False     False     False      True  False  False          True
# 07/12/1912  False     False     False      True  False  False          True
# 08/06/1913   True     False     False     False   True  False          True
# 09/09/1913  False     False     False      True   True  False          True
# 10/17/1913  False     False     False      True   True  False          True
# ...           ...       ...       ...       ...    ...    ...           ...
# 05/20/2009  False     False     False      True  False  False         False
# 05/26/2009   True     False     False      True  False  False         False
# 06/01/2009  False     False     False     False  False  False         False
# 06/07/2009  False     False     False      True  False  False         False
# 06/08/2009   True     False     False      True  False  False          True
#
# ...

# %%
df.drop(['Flight #','Time'],axis =1,inplace=True)

# %%
df
# Out:
#                                                      Location  \
# Date
# 09/17/1908                                Fort Myer, Virginia
# 07/12/1912                            AtlantiCity, New Jersey
# 08/06/1913                 Victoria, British Columbia, Canada
# 09/09/1913                                 Over the North Sea
# 10/17/1913                         Near Johannisthal, Germany
# ...                                                       ...
# 05/20/2009                             Near Madiun, Indonesia
# 05/26/2009                  Near Isiro, DemocratiRepubliCongo
# 06/01/2009  AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009       Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009                  State of Arunachal Pradesh, India
#
#                                    Operator  \
# Date
# 09/17/1908             Military - U.S. Army
# 07/12/1912             Military - U.S. Navy
# 08/06/1913                          Private
# ...

# %%
{column :len(df[column].unique()) for column in df.columns}
# Out:
# {'Location': 4304,
#  'Operator': 2477,
#  'Route': 3245,
#  'Type': 2447,
#  'Registration': 4906,
#  'cn/In': 3708,
#  'Aboard': 240,
#  'Fatalities': 192,
#  'Ground': 51,
#  'Summary': 4674}

# %% [markdown]
# pd.get_dummies(df['Location'])

# %% [markdown]
# df.set_index('Location',inplace=True)
# df.head()

# %%
df.isin(['NaN']).any()
# Out:
# Location        False
# Operator        False
# Route           False
# Type            False
# Registration    False
# cn/In           False
# Aboard          False
# Fatalities      False
# Ground          False
# Summary         False
# dtype: bool

# %%
df
# Out:
#                                                      Location  \
# Date
# 09/17/1908                                Fort Myer, Virginia
# 07/12/1912                            AtlantiCity, New Jersey
# 08/06/1913                 Victoria, British Columbia, Canada
# 09/09/1913                                 Over the North Sea
# 10/17/1913                         Near Johannisthal, Germany
# ...                                                       ...
# 05/20/2009                             Near Madiun, Indonesia
# 05/26/2009                  Near Isiro, DemocratiRepubliCongo
# 06/01/2009  AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009       Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009                  State of Arunachal Pradesh, India
#
#                                    Operator  \
# Date
# 09/17/1908             Military - U.S. Army
# 07/12/1912             Military - U.S. Navy
# 08/06/1913                          Private
# ...

# %%
df['Location']
# Out:
# Date
# 09/17/1908                                  Fort Myer, Virginia
# 07/12/1912                              AtlantiCity, New Jersey
# 08/06/1913                   Victoria, British Columbia, Canada
# 09/09/1913                                   Over the North Sea
# 10/17/1913                           Near Johannisthal, Germany
#                                     ...
# 05/20/2009                               Near Madiun, Indonesia
# 05/26/2009                    Near Isiro, DemocratiRepubliCongo
# 06/01/2009    AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009         Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009                    State of Arunachal Pradesh, India
# Name: Location, Length: 5268, dtype: object

# %%
df["Fatalities"]
# Out:
# Date
# 09/17/1908      1.0
# 07/12/1912      5.0
# 08/06/1913      1.0
# 09/09/1913     14.0
# 10/17/1913     30.0
#               ...
# 05/20/2009     98.0
# 05/26/2009      4.0
# 06/01/2009    228.0
# 06/07/2009      1.0
# 06/08/2009     13.0
# Name: Fatalities, Length: 5268, dtype: float64

# %%
df.isnull().sum()
# Out:
# Location          20
# Operator          18
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
import numpy as np

# %%
df.Location.value_counts()
# Out:
# Sao Paulo, Brazil                    15
# Moscow, Russia                       15
# Rio de Janeiro, Brazil               14
# Anchorage, Alaska                    13
# Manila, Philippines                  13
#                                      ..
# Near Charana, Bolivia                 1
# Monte Matto, Italy                    1
# Misaki Mountain, Japan                1
# Angelholm, Sweden                     1
# State of Arunachal Pradesh, India     1
# Name: Location, Length: 4303, dtype: int64

# %%
df.columns.to_list()
# Out:
# ['Location',
#  'Operator',
#  'Route',
#  'Type',
#  'Registration',
#  'cn/In',
#  'Aboard',
#  'Fatalities',
#  'Ground',
#  'Summary']

# %%
maxoccurance = df.Location.value_counts().idxmax()

# %%
df.Location.replace(np.nan,maxoccurance,inplace=True)

# %%
df.isnull().sum()
# Out:
# Location           0
# Operator          18
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
df.Operator.value_counts()
maxoccurance = df.Operator.value_counts().idxmax()
df.Operator.replace(np.nan,maxoccurance,inplace=True)
df['Operator'].value_counts()
# Out:
# Aeroflot                               197
# Military - U.S. Air Force              176
# Air France                              70
# Deutsche Lufthansa                      65
# China National Aviation Corporation     44
#                                       ...
# Military - Argentine Navy                1
# Richland Flying Service - Air Taxii      1
# Harbor Airlines - Air Taxi               1
# Aerovias Venezolanas SA (Venezuela)      1
# Strait Air                               1
# Name: Operator, Length: 2476, dtype: int64

# %%
df.Route.value_counts()
maxoccurance = df.Route.value_counts().idxmax()
df.Route.replace(np.nan,maxoccurance,inplace=True)
df['Route'].value_counts()
# Out:
# Training                      1787
# Sightseeing                     29
# Test flight                     17
# Test                             6
# Sao Paulo - Rio de Janeiro       5
#                               ...
# Manila - Lapu Lapu               1
# Saint Denis - Paris              1
# Cork - London                    1
# Peoria, IL - St. Louis, MO       1
# Mechuka for Jorhat               1
# Name: Route, Length: 3244, dtype: int64

# %%
df.Type.value_counts()
maxoccurance = df.Type.value_counts().idxmax()
df.Type.replace(np.nan,maxoccurance,inplace=True)
df['Type'].value_counts()
# Out:
# Douglas DC-3                                361
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
#                                            ...
# Boeing 727-21                                 1
# NAMC-YS-11-111                                1
# Lockheed EC-121H                              1
# Cessna 205A                                   1
# Airbus A330-203                               1
# Name: Type, Length: 2446, dtype: int64

# %%
df.Registration.value_counts()
maxoccurance = df.Registration.value_counts().idxmax()
df.Registration.replace(np.nan,maxoccurance,inplace=True)
df['Registration'].value_counts()
# Out:
# 49            338
# N864JA          2
# CCCP-46724      2
# 012             2
# 128441          2
#              ...
# PI-C489         1
# N842D           1
# N724US          1
# CCCP-11193      1
# C-FJJR          1
# Name: Registration, Length: 4905, dtype: int64

# %%
df.rename(columns={

'cn/In':'Serial_Number'
}, inplace=True)
df.head()
# Out:
#                                       Location                Operator  \
# Date
# 09/17/1908                 Fort Myer, Virginia    Military - U.S. Army
# 07/12/1912             AtlantiCity, New Jersey    Military - U.S. Navy
# 08/06/1913  Victoria, British Columbia, Canada                 Private
# 09/09/1913                  Over the North Sea  Military - German Navy
# 10/17/1913          Near Johannisthal, Germany  Military - German Navy
#
#                     Route                    Type Registration Serial_Number  \
# Date
# 09/17/1908  Demonstration        Wright Flyer III           49             1
# 07/12/1912    Test flight               Dirigible           49           NaN
# 08/06/1913       Training        Curtiss seaplane           49           NaN
# 09/09/1913       Training  Zeppelin L-1 (airship)           49           NaN
# 10/17/1913       Training  Zeppelin L-2 (airship)           49           NaN
#
#             Aboard  Fatalities  Ground  \
# Date
# ...

# %%
df.Serial_Number.value_counts()
maxoccurance = df.Serial_Number.value_counts().idxmax()
df.Serial_Number.replace(np.nan,maxoccurance,inplace=True)
df['Serial_Number'].value_counts()
# Out:
# 178         1234
# 229            5
# 19             5
# 213            5
# 125            5
#             ...
# 1114           1
# 19410          1
# 42929          1
# 45794/52       1
# 424            1
# Name: Serial_Number, Length: 3707, dtype: int64

# %%
df.Aboard.value_counts()
maxoccurance = df.Aboard.value_counts().idxmax()
df.Aboard.replace(np.nan,maxoccurance,inplace=True)
df['Aboard'].value_counts()
# Out:
# 2.0      399
# 3.0      370
# 4.0      296
# 5.0      239
# 6.0      223
#         ...
# 240.0      1
# 218.0      1
# 192.0      1
# 269.0      1
# 228.0      1
# Name: Aboard, Length: 239, dtype: int64

# %%
df.Fatalities.value_counts()
maxoccurance = df.Fatalities.value_counts().idxmax()
df.Fatalities.replace(np.nan,maxoccurance,inplace=True)
df['Fatalities'].value_counts()
# Out:
# 2.0      540
# 3.0      458
# 1.0      409
# 4.0      328
# 5.0      260
#         ...
# 256.0      1
# 159.0      1
# 290.0      1
# 259.0      1
# 228.0      1
# Name: Fatalities, Length: 191, dtype: int64

# %%
df.Ground.value_counts()
maxoccurance = df.Ground.value_counts().idxmax()
df.Ground.replace(np.nan,maxoccurance,inplace=True)
df['Ground'].value_counts()
# Out:
# 0.0       5049
# 1.0         53
# 2.0         27
# 3.0         21
# 4.0         15
# 5.0         10
# 8.0         10
# 7.0          8
# 11.0         6
# 6.0          6
# 22.0         5
# 13.0         4
# 24.0         3
# 10.0         3
# 44.0         3
# 20.0         3
# 14.0         2
# 2750.0       2
# 30.0         2
# 12.0         2
# 19.0         2
# 47.0         2
# 52.0         2
# 70.0         2
# 54.0         1
# 18.0         1
# 45.0         1
# 16.0         1
# 35.0         1
# 50.0         1
# 23.0         1
# 225.0        1
# 125.0        1
# 75.0         1
# 15.0         1
# 32.0         1
# 49.0         1
# 9.0          1
# 40.0         1
# 36.0         1
# 113.0        1
# 107.0        1
# 33.0         1
# 87.0         1
# 31.0         1
# 63.0         1
# 17.0         1
# 37.0         1
# 58.0         1
# 85.0         1
# Name: Ground, dtype: int64

# %%
df.Summary.value_counts()
maxoccurance = df.Summary.value_counts().idxmax()
df.Summary.replace(np.nan,maxoccurance,inplace=True)
df['Summary'].value_counts()
# Out:
# Crashed during takeoff.                                                                                                                                                                                                                                                                                                                        405
# Crashed into the sea.                                                                                                                                                                                                                                                                                                                           12
# ...

# %%
df.isnull().sum()
# Out:
# Location         0
# Operator         0
# Route            0
# Type             0
# Registration     0
# Serial_Number    0
# Aboard           0
# Fatalities       0
# Ground           0
# Summary          0
# dtype: int64

# %%
df.isnull()
# Out:
#             Location  Operator  Route   Type  Registration  Serial_Number  \
# Date
# 09/17/1908     False     False  False  False         False          False
# 07/12/1912     False     False  False  False         False          False
# 08/06/1913     False     False  False  False         False          False
# 09/09/1913     False     False  False  False         False          False
# 10/17/1913     False     False  False  False         False          False
# ...              ...       ...    ...    ...           ...            ...
# 05/20/2009     False     False  False  False         False          False
# 05/26/2009     False     False  False  False         False          False
# 06/01/2009     False     False  False  False         False          False
# 06/07/2009     False     False  False  False         False          False
# 06/08/2009     False     False  False  False         False          False
#
#             Aboard  Fatalities  Ground  Summary
# Date
# ...

# %%
df.isnull().sum()
# Out:
# Location         0
# Operator         0
# Route            0
# Type             0
# Registration     0
# Serial_Number    0
# Aboard           0
# Fatalities       0
# Ground           0
# Summary          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['Location'].value_counts()
# Out:
# Sao Paulo, Brazil                    35
# Moscow, Russia                       15
# Rio de Janeiro, Brazil               14
# Manila, Philippines                  13
# Bogota, Colombia                     13
#                                      ..
# Near Charana, Bolivia                 1
# Monte Matto, Italy                    1
# Misaki Mountain, Japan                1
# Angelholm, Sweden                     1
# State of Arunachal Pradesh, India     1
# Name: Location, Length: 4303, dtype: int64

# %%
df.sort_values(by='Location',inplace=True)
df.head()
# Out:
#                                             Location  \
# Date
# 08/01/1948       1,200 miles off Dakar, AtlantiOcean
# 08/10/1997  100 miles SW of Kuujjuaq, Quebec, Canada
# 10/04/2001             110 miles SW of Sochi, Russia
# 11/08/2003          200 miles NE of Derby, Australia
# 01/15/1953                25 nm off Agrigento, Italy
#
#                                    Operator                            Route  \
# Date
# 08/01/1948                       Air France    Fort de France - Port Etienne
# 08/10/1997                          Private                         Training
# 10/04/2001                   Sibir Airlines  Tel Aviv -  Novosibirsk, Russia
# 11/08/2003  Heliwork WA Pty Ltd. - Air Taxi                         Training
# 01/15/1953        Military -Royal Air Force                         Training
#
#                                              Type   Registration  \
# Date
# 08/01/1948            Latecoere 631 (flying boat)         F-BDRC
# ...

# %%
df.sort_values(by='Serial_Number',inplace=True)
df.head()
# Out:
#                                           Location  \
# Date
# 04/12/1973                 Moffett AFB, California
# 06/21/1996                         Shanghai, China
# 11/07/1960                     Near Quito, Ecuador
# 02/25/1962  Portlamar, Margarita Island, Venezuela
# 04/29/1994                  Near El Rosa, Colombia
#
#                                                    Operator  \
# Date
# 04/12/1973                             Military - U.S. Navy
# 06/21/1996  China Flying Dragon Aviation (Feilong Airlines)
# 11/07/1960                                             AREA
# 02/25/1962                                           Avensa
# 04/29/1994                Lineas Aereas de los Libertadores
#
#                                            Route  \
# Date
# 04/12/1973                              Training
# 06/21/1996                     Dalian - Shanghai
# 11/07/1960                     Guayaquil - Quito
# 02/25/1962                     Porlamar - Cumana
# ...

# %%
df.head()
# Out:
#                                           Location  \
# Date
# 04/12/1973                 Moffett AFB, California
# 06/21/1996                         Shanghai, China
# 11/07/1960                     Near Quito, Ecuador
# 02/25/1962  Portlamar, Margarita Island, Venezuela
# 04/29/1994                  Near El Rosa, Colombia
#
#                                                    Operator  \
# Date
# 04/12/1973                             Military - U.S. Navy
# 06/21/1996  China Flying Dragon Aviation (Feilong Airlines)
# 11/07/1960                                             AREA
# 02/25/1962                                           Avensa
# 04/29/1994                Lineas Aereas de los Libertadores
#
#                                            Route  \
# Date
# 04/12/1973                                   NaN
# 06/21/1996                     Dalian - Shanghai
# 11/07/1960                     Guayaquil - Quito
# 02/25/1962                     Porlamar - Cumana
# ...

# %%
df.tail()
# Out:
#                            Location                 Operator  \
# Date
# 10/21/1926          English Channel         Imperial Airways
# 06/17/1929   Off Dungeness, England         Imperial Airways
# 10/30/1930  Near Neufchatel, France         Imperial Airways
# 02/21/2002           Lakhta, Russia  Military - Russian Navy
# 03/25/2000           Huambo, Angola                   Uralex
#
#                                       Route               Type Registration  \
# Date
# 10/21/1926                              NaN  Handley Page W-10       G-EBMS
# 06/17/1929                              NaN  Handley Page W-10       G-EBMT
# 10/30/1930  Paris, France - London, England   Handley Page W-8       G-EBIX
# 02/21/2002                 Sanofov - Lakhta      Antonov AN-26        07RED
# 03/25/2000                  Huambo - Luanda      Antonov AN-32       D2-MAJ
#
#                cn/In Aboard Fatalities Ground  \
# Date
# 10/21/1926     W10/3   12.0        0.0    0.0
# ...

# %%
years = range(1908,2009)

# %%
df.describe()
# Out:
#        Location  Operator Route          Type Registration cn/In  Aboard  \
# count      5268      5268  5268          5268         5268  5268  5268.0
# unique     4304      2477  3245          2447         4906  3708   240.0
# top         NaN  Aeroflot   NaN  Douglas DC-3          NaN   NaN     2.0
# freq         20       179  1706           334          335  1228   377.0
#
#         Fatalities  Ground Summary
# count       5268.0  5268.0    5268
# unique       192.0    51.0    4674
# top            2.0     0.0     NaN
# freq         528.0  5027.0     390

# %%
df
# Out:
#                                           Location  \
# Date
# 04/12/1973                 Moffett AFB, California
# 06/21/1996                         Shanghai, China
# 11/07/1960                     Near Quito, Ecuador
# 02/25/1962  Portlamar, Margarita Island, Venezuela
# 04/29/1994                  Near El Rosa, Colombia
# ...                                            ...
# 10/21/1926                         English Channel
# 06/17/1929                  Off Dungeness, England
# 10/30/1930                 Near Neufchatel, France
# 02/21/2002                          Lakhta, Russia
# 03/25/2000                          Huambo, Angola
#
#                                                    Operator  \
# Date
# 04/12/1973                             Military - U.S. Navy
# 06/21/1996  China Flying Dragon Aviation (Feilong Airlines)
# 11/07/1960                                             AREA
# 02/25/1962                                           Avensa
# ...

# %%
print(df.index.tolist())
# Out:
# ['04/12/1973', '06/21/1996', '11/07/1960', '02/25/1962', '04/29/1994', '03/08/1968', '12/31/1970', '04/04/1975', '11/15/1964', '10/20/1977', '06/06/1996', '12/11/2004', '05/22/2001', '01/31/1971', '10/05/2004', '07/24/1992', '05/07/1964', '08/02/1984', '08/04/1998', '03/14/1957', '12/13/1993', '07/14/2001', '03/23/2005', '03/29/1979', '12/02/1968', '03/11/2007', '05/18/2004', '01/31/2003', '01/15/1963', '04/06/1994', '12/09/1982', '05/08/2003', '03/04/2004', '07/13/1998', '08/14/1972', '02/05/1972', '05/12/1998', '03/08/1962', '07/17/1998', '05/18/2005', '02/09/1992', '06/26/1988', '05/11/1993', '11/27/1996', '05/24/1991', '04/05/1996', '09/27/1942', '01/15/1934', '06/03/1973', '05/10/1990', '08/02/1979', '06/02/1980', '10/06/1996', '02/24/1994', '01/19/1960', '05/09/1982', '01/20/1992', '10/03/2003', '11/08/2003', '03/23/1938', '12/23/2002', '12/22/1995', '12/06/2004', '11/28/1976', '10/13/1973', '10/13/1971', '06/04/1962', '07/13/1963', '10/25/1962', '07/25/1991', '09/12/1990', '03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5268 entries, 04/12/1973 to 03/25/2000
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       5268 non-null   object
#  1   Operator       5268 non-null   object
#  2   Route          5268 non-null   object
#  3   Type           5268 non-null   object
#  4   Registration   5268 non-null   object
#  5   Serial_Number  5268 non-null   object
#  6   Aboard         5268 non-null   float64
#  7   Fatalities     5268 non-null   float64
#  8   Ground         5268 non-null   float64
#  9   Summary        5268 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 452.7+ KB

# %%
df.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5268.000000  5268.000000  5268.000000
# mean     27.447798    20.027145     1.602126
# std      43.018235    33.173297    53.875057
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %%
df
# Out:
#                                           Location  \
# Date
# 04/12/1973                 Moffett AFB, California
# 06/21/1996                         Shanghai, China
# 11/07/1960                     Near Quito, Ecuador
# 02/25/1962  Portlamar, Margarita Island, Venezuela
# 04/29/1994                  Near El Rosa, Colombia
# ...                                            ...
# 10/21/1926                         English Channel
# 06/17/1929                  Off Dungeness, England
# 10/30/1930                 Near Neufchatel, France
# 02/21/2002                          Lakhta, Russia
# 03/25/2000                          Huambo, Angola
#
#                                                    Operator  \
# Date
# 04/12/1973                             Military - U.S. Navy
# 06/21/1996  China Flying Dragon Aviation (Feilong Airlines)
# 11/07/1960                                             AREA
# 02/25/1962                                           Avensa
# ...
