# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuldeepak090/Major-Project-kuldeepak/blob/main/eda_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import numpy as np

# %%
import plotly.io as pio
pio.renderers.default="kaggle"

# %%
pd.set_option('display.max_columns',None)
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] =(15,5)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Kuldeepak090/Major-Project-kuldeepak/main/datasets/cleaned_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    5268 non-null   object
#  1   Operator    5268 non-null   object
#  2   Route       5268 non-null   object
#  3   Type        5268 non-null   object
#  4   Aboard      5268 non-null   float64
#  5   Fatalities  5268 non-null   float64
#  6   Ground      5268 non-null   float64
#  7   Summary     5268 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 329.4+ KB

# %%
print(df.columns.tolist())
# Out:
# ['Location', 'Operator', 'Route', 'Type', 'Aboard', 'Fatalities', 'Ground', 'Summary']

# %%
df['Location'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Operator'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Route'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Type'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Aboard'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Fatalities'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Ground'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
df['Summary'].value_counts().head(20).plot(kind='bar',color = ['pink','orange'])
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='Location',y='Fatalities',data=df)
plt.show()

# %%
sns.scatterplot(x='Aboard',y='Fatalities',data=df)
plt.show()

# %%
sns.scatterplot(x='Type',y='Aboard',data=df)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Location', 'Operator', 'Route', 'Type', 'Aboard', 'Fatalities', 'Ground', 'Summary']

# %%
sns.scatterplot(x='Type',y='Fatalities',data=df)
plt.show()

# %%
sns.scatterplot(x='Operator',y='Aboard',hue ='Fatalities',data=df)
plt.show()

# %%
df
# Out:
#                                     Location  \
# 0                    Moffett AFB, California
# 1                            Shanghai, China
# 2                        Near Quito, Ecuador
# 3     Portlamar, Margarita Island, Venezuela
# 4                     Near El Rosa, Colombia
# ...                                      ...
# 5263                         English Channel
# 5264                  Off Dungeness, England
# 5265                 Near Neufchatel, France
# 5266                          Lakhta, Russia
# 5267                          Huambo, Angola
#
#                                              Operator  \
# 0                                Military - U.S. Navy
# 1     China Flying Dragon Aviation (Feilong Airlines)
# 2                                                AREA
# 3                                              Avensa
# 4                   Lineas Aereas de los Libertadores
# ...                                               ...
# ...

# %%
sns.countplot(x = 'Fatalities',data = df.head(50))
plt.figure(figsize=(20,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x = 'Operator',data = df.head(50))
plt.figure(figsize=(20,10))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
